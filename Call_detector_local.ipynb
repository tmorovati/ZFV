# %%
import os
os.getcwd()
os.listdir()
# Out:
# ['Theunissen-dataset',
#  '.DS_Store',
#  'Papers',
#  'Sound_Event_Detection.ipynb',
#  'OSF-dataset',
#  'Call_detector_local.ipynb',
#  'README.md',
#  '.git',
#  'testing_time_frequency_transformation.ipynb']

# %%
dataset_path = "/Users/tahouramorovati/Documents/Thesis/ZFV/Theunissen-dataset/AdultVocalizations"
list_of_calls = os.listdir(dataset_path)
list_of_calls # 2969 is the number of adult calls we have
# Out:
# ['YelGre5275_110728-DC-26.wav',
#  'BluRas61dd_110406-TetC-15.wav',
#  'LblRed0613_111202-ThukC-01.wav',
#  'YelGre5275_110728-DC-32.wav',
#  'BluRas61dd_110406-TetC-01.wav',
#  'LblRed0613_111013-DC-11.wav',
#  'LblBla4548_130418-Wh-16.wav',
#  'YelGre5275_110629-TukC-12.wav',
#  'GreOra1817_110729-AggC-22.wav',
#  'GraLbl0457_110601-NestC-16.wav',
#  'YelOra2575_110623-TukC-05.wav',
#  'PurRas20dd_110429-DC-09.wav',
#  'LblBla4548_130503-Te-30.wav',
#  'YelGre5275_110623-WhineC-11.wav',
#  'HPiHPi4748_110616-TetC-22.wav',
#  'LblBla4548_130503-Te-24.wav',
#  'WhiRas44dd_110620-DC-08.wav',
#  'WhiRas44dd_110620-DC-20.wav',
#  'Unknown00F_110404-DC-12.wav',
#  'PurRas20dd_110429-DC-21.wav',
#  'GreGre2522_130417-Wh-02.wav',
#  'LblBla4548_130503-Te-18.wav',
#  'WhiBlu5698_110329-TetC-22.wav',
#  'BluRas61dd_110429-DC-33.wav',
#  'YelGre5275_110627-Song-36.wav',
#  'YelOra2575_110615-TetC-29.wav',
#  'WhiRas44dd_110706-NestCSeq-02.wav',
#  'PurRas20dd_110608-NestC-06.wav',
# ...

# %%
list_of_calls[0]
# Out:
# 'YelGre5275_110728-DC-26.wav'

# %%
counter= 0
calls_dict = {'Ag':0,
              'Be':0,
              'DC':0,
              'Di':0,
              'LT':0,
              'Ne':0,
              'So':0,
              'Te':0,
              'Th':0,
              'Tu':0,
              'Wh':0}

for call in list_of_calls:
  if call.endswith(".wav"):
    index = call.find("-")
    for key in calls_dict.keys():
      if call[index+1:index+3]== key:
        calls_dict[key] +=1
      else: 
        counter +=1
        print("now we figure out which files have problems with notating")
        print(call)
        

calls_dict.values()
# Out:
# now we figure out which files have problems with notating
# YelGre5275_110728-DC-26.wav
# now we figure out which files have problems with notating
# YelGre5275_110728-DC-26.wav
# now we figure out which files have problems with notating
# YelGre5275_110728-DC-26.wav
# now we figure out which files have problems with notating
# YelGre5275_110728-DC-26.wav
# now we figure out which files have problems with notating
# YelGre5275_110728-DC-26.wav
# now we figure out which files have problems with notating
# YelGre5275_110728-DC-26.wav
# now we figure out which files have problems with notating
# YelGre5275_110728-DC-26.wav
# now we figure out which files have problems with notating
# YelGre5275_110728-DC-26.wav
# now we figure out which files have problems with notating
# YelGre5275_110728-DC-26.wav
# now we figure out which files have problems with notating
# YelGre5275_110728-DC-26.wav
# now we figure out which files have problems with notating
# BluRas61dd_110406-TetC-15.wav
# ...

# %%
sum(list(calls_dict.values())) # 232 data is lost here.
# in the next step we retrieve them.
# Out:
# 2928

# %%
for call in list_of_calls:
    if call.endswith(".wav"):
        pass 
    else:
        print(call)
