# %% [markdown]
# <a href="https://colab.research.google.com/github/tmorovati/ZFV/blob/main/Call_detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# At first I wanted to use this paper:
# A fast and accurate zebra finch syllable detector - PMC (nih.gov)
#
# and I wanted to use their dataset, which was 3.1 G and in Mat format. Then I changed my mind and used Thenusnan data. Whenever you want to use their data run this code:
#
# !wget -O Birdsong_recordings.zip "https://files.osf.io/v1/resources/bx76r/providers/osfstorage/?zip="
#
#
# and then unzip it:
#
# !unzip Birdsong_recording

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# !wget -O Adult.zip "https://figshare.com/ndownloader/files/21833430"
# Out:
# --2024-05-13 19:17:43--  https://figshare.com/ndownloader/files/21833430
# Resolving figshare.com (figshare.com)... 54.74.37.58, 52.16.41.239, 2a05:d018:1f4:d003:caf8:e116:99cc:6a6b, ...
# Connecting to figshare.com (figshare.com)|54.74.37.58|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/21833430/AdultVocalizations.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20240513/eu-west-1/s3/aws4_request&X-Amz-Date=20240513T191744Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=7a601e8c20877f1bf0bea395a69f60cf270b24af1125b237df106f8d7ea10e7a [following]
# ...

# %%
# !wget -O Chick.zip "https://figshare.com/ndownloader/files/21833436"
# Out:
# --2024-05-13 19:18:23--  https://figshare.com/ndownloader/files/21833436
# Resolving figshare.com (figshare.com)... 54.74.37.58, 52.16.41.239, 2a05:d018:1f4:d003:caf8:e116:99cc:6a6b, ...
# Connecting to figshare.com (figshare.com)|54.74.37.58|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/21833436/ChickVocalizations.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20240513/eu-west-1/s3/aws4_request&X-Amz-Date=20240513T191824Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=56cf1850545476a1eb4036584980317c19b43f1c00570ce91b8c03f971b6743c [following]
# ...

# %%
# !unzip Adult.zip
# Out:
# Archive:  Adult.zip
#   inflating: BlaBla0506_110302-AggC-04.wav
#   inflating: BlaBla0506_110302-AggC-05.wav
#   inflating: BlaBla0506_110302-DC-01.wav
#   inflating: BlaBla0506_110302-DC-02.wav
#   inflating: BlaBla0506_110302-DC-05.wav
#   inflating: BlaBla0506_110302-DC-06.wav
#   inflating: BlaBla0506_110302-DC-08.wav
#   inflating: BlaBla0506_110302-DC-10.wav
#   inflating: BlaBla0506_110302-DC-11.wav
#   inflating: BlaBla0506_110302-DC-12.wav
#   inflating: BlaBla0506_110302-DC-13.wav
#   inflating: BlaBla0506_110302-DC-14.wav
#   inflating: BlaBla0506_110302-DC-15.wav
#   inflating: BlaBla0506_110302-DC-16.wav
#   inflating: BlaBla0506_110302-NekakleC-02.wav
#   inflating: BlaBla0506_110302-NekakleC-03.wav
#   inflating: BlaBla0506_110302-NekakleC-04.wav
#   inflating: BlaBla0506_110302-NekakleC-05.wav
#   inflating: BlaBla0506_110302-NekakleC-05a.wav
#   inflating: BlaBla0506_110302-NekakleC-05b.wav
#   inflating: BlaBla0506_110302-NekakleC-05c.wav
# ...

# %%
# !unzip Chick.zip
# Out:
# Archive:  Chick.zip
#   inflating: GraGre0813_110217-Beggseq-01.wav
#   inflating: GraGre0813_110217-Beggseq-02.wav
#   inflating: GraGre0813_110217-Beggseq-03.wav
#   inflating: GraGre0813_110217-Beggseq-04.wav
#   inflating: GraGre0813_110217-Beggseq-05.wav
#   inflating: GraGre0813_110217-Beggseq-07.wav
#   inflating: GraGre0813_110217-Beggseq-09.wav
#   inflating: GraGre0813_110218-Beggseq-01.wav
#   inflating: GraGre0813_110218-Beggseq-01cut.wav
#   inflating: GraGre0813_110218-Beggseq-02.wav
#   inflating: GraGre0813_110218-Beggseq-03.wav
#   inflating: GraGre0813_110218-Beggseq-04.wav
#   inflating: GraGre0813_110218-Beggseq-05.wav
#   inflating: GraGre0813_110218-Beggseq-06.wav
#   inflating: GraGre0813_110218-Beggseq-07.wav
#   inflating: GraGre0813_110218-Beggseq-08.wav
#   inflating: GraGre0813_110218-Beggseq-09.wav
#   inflating: GraGre0813_110218-Beggseq-10.wav
#   inflating: GraGre0813_110218-Beggseq-11.wav
#   inflating: GraGre0813_110218-Beggseq-12.wav
# ...

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
call ="BlaLbl8026_110609-WhiCNestC-32c.wav"
calls_dict = {"Ag":0,
              "Be":0,
              "DC":0,
              "Di":0,
              "LT":0,
              "Ne":0,
              "So":0,
              "Te":0,
              "Th":0,
              "Tu":0,
              "Wh":0}

print(calls_dict.keys())
if call.endswith(".wav"):
  index = call.find("-")
  if call[index+1:index+3] in calls_dict.items():
      #index = calls_dict.keys().items(call[index+1:index+3])
      print("jgdfgdfgdf")
# Out:
# dict_keys(['Ag', 'Be', 'DC', 'Di', 'LT', 'Ne', 'So', 'Te', 'Th', 'Tu', 'Wh'])

# %%
list_of_calls = list(os.listdir(os.getcwd()))
Calls_dict = {Ag:0,
              Be:0,
              DC:0,
              Di:0,
              LT:0,
              Ne:0,
              S0:0,
              Te:0,
              Th:0,
              Tu:0,
              Wh:0}

for call in list_of_calls:
  if call.endswith(".wav"):
    index = call.find("-")
    particular_call = call[index+1,index+2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-973f7de53c0e> in <cell line: 2>()
#       1 list_of_calls = list(os.listdir(os.getcwd()))
# ----> 2 if list_of_calls.endswith(".wav"):
#       3   print("fd")
#
# AttributeError: 'list' object has no attribute 'endswith'
